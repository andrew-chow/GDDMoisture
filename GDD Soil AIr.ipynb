# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from GDD_functions import cleaner_copr, cleaner_air, ndvi_cleaner, ndvi_thresh_date,GDD_calc
import matplotlib.lines as lines
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn import linear_model

# %%
air2010= pd.read_csv('Air 2010-2011.csv')
air2011= pd.read_csv('Air 2011-2012.csv')
air2012= pd.read_csv('Air 2012-2013.csv')
air2013= pd.read_csv('Air 2013-2014.csv')
air2014= pd.read_csv('Air 2014-2015.csv')
air2015= pd.read_csv('Air 2015-2016.csv')
air2016= pd.read_csv('Air 2016-2017.csv')
air2017= pd.read_csv('Air 2017-2018.csv')
air2018= pd.read_csv('Air 2018-2019.csv')
air2019= pd.read_csv('Air 2019-2020.csv')
ndvi2010= pd.read_csv('NDVI Air 2010-2011.csv')
ndvi2011= pd.read_csv('NDVI Air 2011-2012.csv')
ndvi2012= pd.read_csv('NDVI Air 2012-2013.csv')
ndvi2013= pd.read_csv('NDVI Air 2013-2014.csv')
ndvi2014= pd.read_csv('NDVI Air 2014-2015.csv')
ndvi2015= pd.read_csv('NDVI Air 2015-2016.csv')
ndvi2016= pd.read_csv('NDVI Air 2016-2017.csv')
ndvi2017= pd.read_csv('NDVI Air 2017-2018.csv')
ndvi2018= pd.read_csv('NDVI Air 2018-2019.csv')
ndvi2019= pd.read_csv('NDVI Air 2019-2020.csv')

# %%
soil2010= pd.read_csv('Air SM 2010.csv')
soil2011= pd.read_csv('Air SM 2011.csv')
soil2012= pd.read_csv('Air SM 2012.csv')
soil2013= pd.read_csv('Air SM 2013.csv')
soil2014= pd.read_csv('Air SM 2014.csv')
soil2015= pd.read_csv('Air SM 2015.csv')
soil2018= pd.read_csv('Air SM 2018.csv')
soil2019= pd.read_csv('Air SM 2019.csv')

# %%
rain2010 = pd.read_csv('Air Rain 2010.csv')
rain2011 = pd.read_csv('Air Rain 2011.csv')
rain2012 = pd.read_csv('Air Rain 2012.csv')
rain2013 = pd.read_csv('Air Rain 2013.csv')
rain2014 = pd.read_csv('Air Rain 2014.csv')
rain2015 = pd.read_csv('Air Rain 2015.csv')
rain2016 = pd.read_csv('Air Rain 2016.csv')
rain2017 = pd.read_csv('Air Rain 2017.csv')
rain2018 = pd.read_csv('Air Rain 2018.csv')
rain2019 = pd.read_csv('Air Rain 2019.csv')

# %%
#Initialize array of GDD's
Year_GDD = []
filt2010= cleaner_air(air2010)
ndvi_clean2010= ndvi_cleaner(ndvi2010)
thresh_date2010= ndvi_thresh_date(ndvi_clean2010,filt2010)
GDD2010=GDD_calc(filt2010,thresh_date2010)
Year_GDD = np.append(Year_GDD,GDD2010)
filt2011= cleaner_air(air2011)
ndvi_clean2011= ndvi_cleaner(ndvi2011)
thresh_date2011= ndvi_thresh_date(ndvi_clean2011,filt2011)
GDD2011=GDD_calc(filt2011,thresh_date2011)
Year_GDD = np.append(Year_GDD,GDD2011)
filt2012= cleaner_air(air2012)
ndvi_clean2012= ndvi_cleaner(ndvi2012)
thresh_date2012= ndvi_thresh_date(ndvi_clean2012,filt2012)
GDD2012=GDD_calc(filt2012,thresh_date2012)
Year_GDD = np.append(Year_GDD,GDD2012)
filt2013= cleaner_air(air2013)
ndvi_clean2013= ndvi_cleaner(ndvi2013)
thresh_date2013= ndvi_thresh_date(ndvi_clean2013,filt2013)
GDD2013=GDD_calc(filt2013,thresh_date2013)
Year_GDD = np.append(Year_GDD,GDD2013)
filt2014= cleaner_air(air2014)
ndvi_clean2014= ndvi_cleaner(ndvi2014)
thresh_date2014= ndvi_thresh_date(ndvi_clean2014,filt2014)
GDD2014=GDD_calc(filt2014,thresh_date2014)
Year_GDD = np.append(Year_GDD,GDD2014)
filt2015= cleaner_air(air2015)
ndvi_clean2015= ndvi_cleaner(ndvi2015)
thresh_date2015= ndvi_thresh_date(ndvi_clean2015,filt2015)
GDD2015=GDD_calc(filt2015,thresh_date2015)
Year_GDD = np.append(Year_GDD,GDD2015)
filt2016= cleaner_air(air2016)
ndvi_clean2016= ndvi_cleaner(ndvi2016)
thresh_date2016= ndvi_thresh_date(ndvi_clean2016,filt2016)
GDD2016=GDD_calc(filt2016,thresh_date2016)
Year_GDD = np.append(Year_GDD,GDD2016)
filt2017= cleaner_air(air2017)
ndvi_clean2017= ndvi_cleaner(ndvi2017)
thresh_date2017= ndvi_thresh_date(ndvi_clean2017,filt2017)
GDD2017=GDD_calc(filt2017,thresh_date2017)
Year_GDD = np.append(Year_GDD,GDD2017)
filt2018= cleaner_air(air2018)
ndvi_clean2018= ndvi_cleaner(ndvi2018)
thresh_date2018= ndvi_thresh_date(ndvi_clean2018,filt2018)
GDD2018=GDD_calc(filt2018,thresh_date2018)
Year_GDD = np.append(Year_GDD,GDD2018)
filt2019= cleaner_air(air2019)
ndvi_clean2019= ndvi_cleaner(ndvi2019)
thresh_date2019= ndvi_thresh_date(ndvi_clean2019,filt2019)
GDD2019=GDD_calc(filt2019,thresh_date2019)
Year_GDD = np.append(Year_GDD,GDD2019)

# %%
Year_GDD
# Out:
# array([ 574.86  ,  693.479 ,  740.93  , 1386.8615,  817.189 ,  909.01  ,
#         657.655 , 1352.8245,  819.065 ,  826.951 ])

# %%
years = []
for i in range(2010,2020):
    years=np.append(years,i)
DF_dic = {'Year': years, 'GDD': Year_GDD }
Df = pd.DataFrame(data=DF_dic)
Df
# Out:
#      Year        GDD
# 0  2010.0   574.8600
# 1  2011.0   693.4790
# 2  2012.0   740.9300
# 3  2013.0  1386.8615
# 4  2014.0   817.1890
# 5  2015.0   909.0100
# 6  2016.0   657.6550
# 7  2017.0  1352.8245
# 8  2018.0   819.0650
# 9  2019.0   826.9510

# %%
plt.plot(Df.Year, Df.GDD)
plt.title("AIRS Observed Growing Degree Days Without Soil Moisture Thresh")
plt.xlabel("Year")
plt.ylabel("Cumulative Temps (GDD) until Green")
# Out:
# Text(0, 0.5, 'Cumulative Temps (GDD) until Green')

# %%
box2010 = {"Year": [2010]*len(filt2010.Date), 'Temp': filt2010.Mid, 'Date': filt2010.Date}
box_data10= pd.DataFrame(box2010)
box2011 = {"Year": [2011]*len(filt2011.Date), 'Temp': filt2011.Mid, 'Date': filt2011.Date}
box_data11= pd.DataFrame(box2011)
box2012 = {"Year": [2012]*len(filt2012.Date), 'Temp': filt2012.Mid, 'Date': filt2012.Date}
box_data12= pd.DataFrame(box2012)
box2013 = {"Year": [2013]*len(filt2013.Date), 'Temp': filt2013.Mid, 'Date': filt2013.Date}
box_data13= pd.DataFrame(box2013)
box2014 = {"Year": [2014]*len(filt2014.Date), 'Temp': filt2014.Mid, 'Date': filt2014.Date}
box_data14= pd.DataFrame(box2014)
box2015 = {"Year": [2015]*len(filt2015.Date), 'Temp': filt2015.Mid, 'Date': filt2015.Date}
box_data15= pd.DataFrame(box2015)
box2016 = {"Year": [2016]*len(filt2016.Date), 'Temp': filt2016.Mid, 'Date': filt2016.Date}
box_data16= pd.DataFrame(box2016)
box2017 = {"Year": [2017]*len(filt2017.Date), 'Temp': filt2017.Mid, 'Date': filt2017.Date}
box_data17= pd.DataFrame(box2017)
box2018 = {"Year": [2018]*len(filt2018.Date), 'Temp': filt2018.Mid, 'Date': filt2018.Date}
box_data18= pd.DataFrame(box2018)
box2019 = {"Year": [2019]*len(filt2019.Date), 'Temp': filt2019.Mid, 'Date': filt2019.Date}
box_data19= pd.DataFrame(box2019)

# %%
box= pd.concat([box_data10,box_data11,box_data12,box_data13,box_data14,box_data15,box_data16,box_data17,box_data18,box_data19])
box
# Out:
#      Year     Temp       Date
# 0    2010  23.3200 2010-09-30
# 1    2010  25.4100 2010-10-01
# 2    2010  23.3200 2010-10-02
# 3    2010  18.1800 2010-10-03
# 4    2010  13.7250 2010-10-04
# ..    ...      ...        ...
# 209  2019  18.1550 2020-04-26
# 210  2019  17.5960 2020-04-27
# 211  2019  20.7200 2020-04-28
# 212  2019  19.9200 2020-04-29
# 213  2019  19.1575 2020-04-30
#
# [2133 rows x 3 columns]

# %%
ax= sns.boxplot(x="Year", y="Temp", data=box)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot('Date', 'Mid', data=filt2010)
plt.axvline(x=thresh_date2010, label='line at x = {}'.format(thresh_date2010), c='green')
plt.title("2010-2011 Daily Avrg Temperatures",fontsize=20)
plt.xlabel("Date",fontsize=20)
plt.ylabel("Temp (C)",fontsize=20)
plt.legend(loc='best')
plt.savefig('2010temp.png')

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot('Date', 'Mid', data=filt2011)
plt.axvline(x=thresh_date2011, label='line at x = {}'.format(thresh_date2011), c='green')
plt.title("2011-2012 Daily Avrg Temperatures",fontsize=20)
plt.xlabel("Date",fontsize=20)
plt.ylabel("Temp (C)",fontsize=20)
plt.legend(loc='best')
plt.savefig('2011temp.png')

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot('Date', 'Mid', data=filt2013)
plt.axvline(x=thresh_date2013, label='line at x = {}'.format(thresh_date2013), c='green')
plt.title("2013-2014 Daily Avrg Temperatures",fontsize=20)
plt.xlabel("Date",fontsize=20)
plt.ylabel("Temp (C)",fontsize=20)
plt.legend(loc='best')
plt.savefig('2013temp.png')

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot('Date', 'Mid', data=filt2014)
plt.axvline(x=thresh_date2014, label='line at x = {}'.format(thresh_date2014), c='green')
plt.title("2014-2015 Daily Avrg Temperatures",fontsize=20)
plt.xlabel("Date",fontsize=20)
plt.ylabel("Temp (C)",fontsize=20)
plt.legend(loc='best')
plt.savefig('2014temp.png')

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot('Date', 'Mid', data=filt2015)
plt.axvline(x=thresh_date2015, label='line at x = {}'.format(thresh_date2015), c='green')
plt.title("2015-2016 Daily Avrg Temperatures",fontsize=20)
plt.xlabel("Date",fontsize=20)
plt.ylabel("Temp (C)",fontsize=20)
plt.legend(loc='best')
plt.savefig('2015temp.png')

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot('Date', 'Mid', data=filt2018)
plt.axvline(x=thresh_date2018, label='line at x = {}'.format(thresh_date2018), c='green')
plt.title("2018-2019 Daily Avrg Temperatures",fontsize=20)
plt.xlabel("Date",fontsize=20)
plt.ylabel("Temp (C)",fontsize=20)
plt.legend(loc='best')
plt.savefig('2018temp.png')

# %%
#looking at relationship between mean temp and GDD
Year_mean= box.groupby('Year',as_index=False).mean()
Year_mean
filt2010
# Out:
#           Date     Min    Max      Mid      GDD       Cumu  Year  Index
# 0   2010-09-30  16.530  30.11  23.3200  17.3200    17.3200  2010      0
# 1   2010-10-01  16.650  34.17  25.4100  19.4100    36.7300  2010      1
# 2   2010-10-02  14.630  32.01  23.3200  17.3200    54.0500  2010      2
# 3   2010-10-03   9.930  26.43  18.1800  12.1800    66.2300  2010      3
# 4   2010-10-04  10.360  17.09  13.7250   7.7250    73.9550  2010      4
# ..         ...     ...    ...      ...      ...        ...   ...    ...
# 208 2011-04-26   6.445  24.00  15.2225   9.2225  1258.2970  2010    208
# 209 2011-04-27   2.838  24.18  13.5090   7.5090  1265.8060  2010    209
# 210 2011-04-28   2.967  23.16  13.0635   7.0635  1272.8695  2010    210
# 211 2011-04-29   3.481  21.04  12.2605   6.2605  1279.1300  2010    211
# 212 2011-04-30   6.397  23.91  15.1535   9.1535  1288.2835  2010    212
#
# [213 rows x 8 columns]

# %%
Year_mean['GDD']= Df.GDD
Year_mean
sns.scatterplot(x= 'Temp', y= 'GDD', data= Year_mean)

# %%
def mean_temps(df, date):
    dff2 =df[df.Date <date]
    x=np.mean(dff2.Mid)
    return(x)

# %%
temp2010mean = mean_temps(filt2010, thresh_date2010)
temp2011mean = mean_temps(filt2011, thresh_date2011)
temp2012mean = mean_temps(filt2012, thresh_date2012)
temp2013mean = mean_temps(filt2013, thresh_date2013)
temp2014mean = mean_temps(filt2014, thresh_date2014)
temp2015mean = mean_temps(filt2015, thresh_date2015)
temp2016mean = mean_temps(filt2016, thresh_date2016)
temp2017mean = mean_temps(filt2017, thresh_date2017)
temp2018mean = mean_temps(filt2018, thresh_date2018)
temp2019mean = mean_temps(filt2019, thresh_date2019)

# %%
mean_temps_arr = [temp2010mean,temp2011mean,temp2012mean,temp2013mean,temp2014mean,temp2015mean,temp2016mean,temp2017mean,temp2018mean,temp2019mean]
mean_temps_dict = {'Temp': mean_temps_arr}
df_temps = pd.DataFrame(mean_temps_dict)
df_temps['Year']= Year_mean['Year']
df_temps['GDD']= Df.GDD
df_temps
# Out:
#         Temp  Year        GDD
# 0  14.580000  2010   574.8600
# 1  13.377436  2011   693.4790
# 2  15.261625  2012   740.9300
# 3  13.747830  2013  1386.8615
# 4  16.476782  2014   817.1890
# 5  13.046589  2015   909.0100
# 6  15.815746  2016   657.6550
# 7  15.018830  2017  1352.8245
# 8  15.202978  2018   819.0650
# 9  14.988598  2019   826.9510

# %%
ax=sns.scatterplot(x= 'Temp', y= 'GDD', data= df_temps)
ax.set(xlabel="Mean Temp (C)", ylabel = "GDD", title='Mean Temps Observed before Green')
# Out:
# [Text(0, 0.5, 'GDD'),
#  Text(0.5, 0, 'Mean Temp (C)'),
#  Text(0.5, 1.0, 'Mean Temps Observed before Green')]

# %%
filt2010.GDD
# Out:
# 0      17.3200
# 1      19.4100
# 2      17.3200
# 3      12.1800
# 4       7.7250
#         ...
# 208     9.2225
# 209     7.5090
# 210     7.0635
# 211     6.2605
# 212     9.1535
# Name: GDD, Length: 213, dtype: float64

# %%
cumuGdd= np.cumsum(filt2010.GDD)
CumGDD2010= filt2010
CumGDD2010['Cumu']= cumuGdd
transcum2010 = CumGDD2010[CumGDD2010['Date'] <thresh_date2010]
transcum2010
# Out:
#          Date     Min    Max     Mid     GDD     Cumu
# 0  2010-09-30  16.530  30.11  23.320  17.320   17.320
# 1  2010-10-01  16.650  34.17  25.410  19.410   36.730
# 2  2010-10-02  14.630  32.01  23.320  17.320   54.050
# 3  2010-10-03   9.930  26.43  18.180  12.180   66.230
# 4  2010-10-04  10.360  17.09  13.725   7.725   73.955
# ..        ...     ...    ...     ...     ...      ...
# 62 2010-12-01   0.892  19.58  10.236   4.236  549.119
# 63 2010-12-02   4.582  22.79  13.686   7.686  556.805
# 64 2010-12-03   5.526  20.03  12.778   6.778  563.583
# 65 2010-12-04   6.246  16.36  11.303   5.303  568.886
# 66 2010-12-05   5.378  18.57  11.974   5.974  574.860
#
# [67 rows x 6 columns]

# %%
cumuGdd= np.cumsum(filt2011.GDD)
CumGDD2011= filt2011
CumGDD2011['Cumu']= cumuGdd
transcum2011 = CumGDD2011[CumGDD2011['Date'] <thresh_date2011]
transcum2011
# Out:
#          Date    Min    Max      Mid      GDD      Cumu
# 0  2011-09-30  9.510  22.82  16.1650  10.1650   10.1650
# 1  2011-10-01  7.668  31.22  19.4440  13.4440   23.6090
# 2  2011-10-02  9.090  27.46  18.2750  12.2750   35.8840
# 3  2011-10-03  6.478  23.24  14.8590   8.8590   44.7430
# 4  2011-10-04  8.050  17.96  13.0050   7.0050   51.7480
# ..        ...    ...    ...      ...      ...       ...
# 89 2011-12-28  4.025  24.86  14.4425   8.4425  658.6300
# 90 2011-12-29  6.373  24.58  15.4765   9.4765  668.1065
# 91 2011-12-30  2.880  20.30  11.5900   5.5900  673.6965
# 92 2011-12-31  1.855  25.16  13.5075   7.5075  681.2040
# 93 2012-01-01  8.700  27.85  18.2750  12.2750  693.4790
#
# [94 rows x 6 columns]

# %%
cumuGdd= np.cumsum(filt2012.GDD)
CumGDD2012= filt2012
CumGDD2012['Cumu']= cumuGdd
transcum2012 = CumGDD2012[CumGDD2010['Date'] <thresh_date2012]
transcum2012
# Out:
#           Date     Min    Max      Mid      GDD      Cumu
# 0   2012-09-30  20.130  34.32  27.2250  21.2250    21.225
# 1   2012-10-01  19.270  40.48  29.8750  23.8750    45.100
# 2   2012-10-02  18.630  39.53  29.0800  23.0800    68.180
# 3   2012-10-03   9.140  31.70  20.4200  14.4200    82.600
# 4   2012-10-04   8.060  27.13  17.5950  11.5950    94.195
# ..         ...     ...    ...      ...      ...       ...
# 208 2013-04-26   3.395  25.86  14.6275   8.6275  1383.003
# 209 2013-04-27   2.868  29.00  15.9340   9.9340  1392.937
# 210 2013-04-28   4.636  29.65  17.1430  11.1430  1404.080
# 211 2013-04-29   4.884  29.85  17.3670  11.3670  1415.447
# 212 2013-04-30   6.716  22.79  14.7530   8.7530  1424.200
#
# [213 rows x 6 columns]

# %%
cumuGdd= np.cumsum(filt2013.GDD)
CumGDD2013= filt2013
CumGDD2013['Cumu']= cumuGdd
transcum2013 = CumGDD2013[CumGDD2013['Date'] <thresh_date2013]
transcum2013
# Out:
#           Date     Min    Max      Mid      GDD       Cumu
# 0   2013-09-30  11.200  23.39  17.2950  11.2950    11.2950
# 1   2013-10-01   6.818  27.53  17.1740  11.1740    22.4690
# 2   2013-10-02   6.768  24.53  15.6490   9.6490    32.1180
# 3   2013-10-03   4.810  27.95  16.3800  10.3800    42.4980
# 4   2013-10-04   6.190  29.14  17.6650  11.6650    54.1630
# ..         ...     ...    ...      ...      ...        ...
# 174 2014-03-23   3.573  20.93  12.2515   6.2515  1364.3910
# 175 2014-03-24   2.627  22.24  12.4335   6.4335  1370.8245
# 176 2014-03-25   6.062  19.55  12.8060   6.8060  1377.6305
# 177 2014-03-26   6.477  14.82  10.6485   4.6485  1382.2790
# 178 2014-03-27   4.585  16.58  10.5825   4.5825  1386.8615
#
# [179 rows x 6 columns]

# %%
cumuGdd= np.cumsum(filt2014.GDD)
CumGDD2014= filt2014
CumGDD2014['Cumu']= cumuGdd
transcum2014 = CumGDD2014[CumGDD2014['Date'] <thresh_date2014]
transcum2014
cumuGdd= np.cumsum(filt2015.GDD)
CumGDD2015= filt2015
CumGDD2015['Cumu']= cumuGdd
transcum2015 = CumGDD2015[CumGDD2015['Date'] <thresh_date2015]
transcum2015
# Out:
#           Date     Min    Max      Mid      GDD      Cumu
# 0   2015-09-30  11.720  27.40  19.5600  13.5600   13.5600
# 1   2015-10-01  10.460  28.87  19.6650  13.6650   27.2250
# 2   2015-10-02  12.190  29.47  20.8300  14.8300   42.0550
# 3   2015-10-03   8.980  29.00  18.9900  12.9900   55.0450
# 4   2015-10-04   9.120  19.91  14.5150   8.5150   63.5600
# ..         ...     ...    ...      ...      ...       ...
# 124 2016-02-01   2.709  11.37   7.0395   1.0395  900.1770
# 125 2016-02-02  -3.397  12.08   4.3415  -1.6585  898.5185
# 126 2016-02-03  -1.218  16.10   7.4410   1.4410  899.9595
# 127 2016-02-04  -0.116  18.09   8.9870   2.9870  902.9465
# 128 2016-02-05   3.327  20.80  12.0635   6.0635  909.0100
#
# [129 rows x 6 columns]

# %%
cumuGdd= np.cumsum(filt2016.GDD)
CumGDD2016= filt2016
CumGDD2016['Cumu']= cumuGdd
transcum2016 = CumGDD2016[CumGDD2016['Date'] <thresh_date2016]
transcum2016
# Out:
#          Date    Min    Max      Mid      GDD      Cumu
# 0  2016-09-30  8.080  24.05  16.0650  10.0650   10.0650
# 1  2016-10-01  5.460  28.51  16.9850  10.9850   21.0500
# 2  2016-10-02  3.426  22.09  12.7580   6.7580   27.8080
# 3  2016-10-03  4.805  24.28  14.5425   8.5425   36.3505
# 4  2016-10-04  3.957  25.32  14.6385   8.6385   44.9890
# ..        ...    ...    ...      ...      ...       ...
# 62 2016-12-01  3.162  17.48  10.3210   4.3210  641.6810
# 63 2016-12-02  1.479  16.35   8.9145   2.9145  644.5955
# 64 2016-12-03 -0.868  18.53   8.8310   2.8310  647.4265
# 65 2016-12-04  2.269  21.47  11.8695   5.8695  653.2960
# 66 2016-12-05  1.418  19.30  10.3590   4.3590  657.6550
#
# [67 rows x 6 columns]

# %%
cumuGdd= np.cumsum(filt2017.GDD)
CumGDD2017= filt2017
CumGDD2017['Cumu']= cumuGdd
transcum2017 = CumGDD2017[CumGDD2017['Date'] <thresh_date2017]
transcum2017
# Out:
#           Date    Min    Max      Mid      GDD       Cumu
# 0   2017-09-30  7.922  21.00  14.4610   8.4610     8.4610
# 1   2017-10-01  7.277  31.88  19.5785  13.5785    22.0395
# 2   2017-10-02  4.567  27.08  15.8235   9.8235    31.8630
# 3   2017-10-03  4.953  18.78  11.8665   5.8665    37.7295
# 4   2017-10-04  2.717  28.98  15.8485   9.8485    47.5780
# ..         ...    ...    ...      ...      ...        ...
# 145 2018-02-22 -2.449  12.39   4.9705  -1.0295  1349.5580
# 146 2018-02-23  1.016  11.57   6.2930   0.2930  1349.8510
# 147 2018-02-24 -3.960  16.16   6.1000   0.1000  1349.9510
# 148 2018-02-25  0.046  18.97   9.5080   3.5080  1353.4590
# 149 2018-02-26 -2.869  13.60   5.3655  -0.6345  1352.8245
#
# [150 rows x 6 columns]

# %%
cumuGdd= np.cumsum(filt2018.GDD)
CumGDD2018= filt2018
CumGDD2018['Cumu']= cumuGdd
transcum2018 = CumGDD2018[CumGDD2018['Date'] <thresh_date2018]
transcum2018
# Out:
#          Date     Min    Max      Mid      GDD      Cumu
# 0  2018-09-30   8.760  22.91  15.8350   9.8350    9.8350
# 1  2018-10-01   6.733  33.25  19.9915  13.9915   23.8265
# 2  2018-10-02  13.220  29.29  21.2550  15.2550   39.0815
# 3  2018-10-03  13.230  19.00  16.1150  10.1150   49.1965
# 4  2018-10-04  10.030  26.05  18.0400  12.0400   61.2365
# ..        ...     ...    ...      ...      ...       ...
# 84 2018-12-23   3.855  20.92  12.3875   6.3875  805.2605
# 85 2018-12-24   3.205  18.05  10.6275   4.6275  809.8880
# 86 2018-12-25   6.191  13.61   9.9005   3.9005  813.7885
# 87 2018-12-26   1.955  17.32   9.6375   3.6375  817.4260
# 88 2018-12-27   0.268  15.01   7.6390   1.6390  819.0650
#
# [89 rows x 6 columns]

# %%
cumuGdd= np.cumsum(filt2019.GDD)
CumGDD2019= filt2019
CumGDD2019['Cumu']= cumuGdd
transcum2019 = CumGDD2019[CumGDD2019['Date'] <thresh_date2019]
transcum2019
# Out:
#          Date    Min    Max      Mid      GDD      Cumu
# 0  2019-09-30  7.858  17.54  12.6990   6.6990    6.6990
# 1  2019-10-01  3.582  24.26  13.9210   7.9210   14.6200
# 2  2019-10-02  4.658  28.84  16.7490  10.7490   25.3690
# 3  2019-10-03  6.586  28.88  17.7330  11.7330   37.1020
# 4  2019-10-04  5.069  27.15  16.1095  10.1095   47.2115
# ..        ...    ...    ...      ...      ...       ...
# 87 2019-12-26  1.133  11.76   6.4465   0.4465  815.5540
# 88 2019-12-27 -0.382  15.23   7.4240   1.4240  816.9780
# 89 2019-12-28 -1.406  16.38   7.4870   1.4870  818.4650
# 90 2019-12-29  1.263  15.10   8.1815   2.1815  820.6465
# 91 2019-12-30  6.879  17.73  12.3045   6.3045  826.9510
#
# [92 rows x 6 columns]

# %%
transcum2010['Year']= [2010]*len(transcum2010)
transcum2011['Year']= [2011]*len(transcum2011)
transcum2012['Year']= [2012]*len(transcum2012)
transcum2013['Year']= [2013]*len(transcum2013)
transcum2014['Year']= [2014]*len(transcum2014)
transcum2015['Year']= [2015]*len(transcum2015)
transcum2016['Year']= [2016]*len(transcum2016)
transcum2017['Year']= [2017]*len(transcum2017)
transcum2018['Year']= [2018]*len(transcum2018)
transcum2019['Year']= [2019]*len(transcum2019)
# Out:
# C:\Users\A Chow\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\A Chow\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\A Chow\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
test = {'Date': transcum2010['Date'], 'GDD':transcum2010['Cumu'], 'Year': transcum2010['Year']}
test= pd.DataFrame(test)

# %%
transcum2010['Index'] = range(len(transcum2010.Cumu)) 
transcum2010
# Out:
# C:\Users\A Chow\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          Date     Min    Max     Mid     GDD     Cumu  Year  Index
# 0  2010-09-30  16.530  30.11  23.320  17.320   17.320  2010      0
# 1  2010-10-01  16.650  34.17  25.410  19.410   36.730  2010      1
# 2  2010-10-02  14.630  32.01  23.320  17.320   54.050  2010      2
# 3  2010-10-03   9.930  26.43  18.180  12.180   66.230  2010      3
# 4  2010-10-04  10.360  17.09  13.725   7.725   73.955  2010      4
# ..        ...     ...    ...     ...     ...      ...   ...    ...
# 62 2010-12-01   0.892  19.58  10.236   4.236  549.119  2010     62
# ...

# %%
x1 = transcum2011[['Date', 'Cumu', 'Year']]
x2 = transcum2012[['Date', 'Cumu', 'Year']]
x3 = transcum2013[['Date', 'Cumu', 'Year']]
x4 = transcum2014[['Date', 'Cumu', 'Year']]
x5 = transcum2015[['Date', 'Cumu', 'Year']]
x6 = transcum2016[['Date', 'Cumu', 'Year']]
x7 = transcum2017[['Date', 'Cumu', 'Year']]
x8 = transcum2018[['Date', 'Cumu', 'Year']]
x9 = transcum2019[['Date', 'Cumu', 'Year']]

# %%
CumGDD2010['Year']= [2010]*len(CumGDD2010)
CumGDD2011['Year']= [2011]*len(CumGDD2011)
CumGDD2012['Year']= [2012]*len(CumGDD2012)
CumGDD2013['Year']= [2013]*len(CumGDD2013)
CumGDD2014['Year']= [2014]*len(CumGDD2014)
CumGDD2015['Year']= [2015]*len(CumGDD2015)
CumGDD2016['Year']= [2016]*len(CumGDD2016)
CumGDD2017['Year']= [2017]*len(CumGDD2017)
CumGDD2018['Year']= [2018]*len(CumGDD2018)
CumGDD2019['Year']= [2019]*len(CumGDD2019)
CumGDD2010['Index']= range(len(CumGDD2010.Cumu)) 
CumGDD2011['Index']= range(len(CumGDD2011.Cumu)) 
CumGDD2012['Index']= range(len(CumGDD2012.Cumu)) 
CumGDD2013['Index']= range(len(CumGDD2013.Cumu)) 
CumGDD2014['Index']= range(len(CumGDD2014.Cumu)) 
CumGDD2015['Index']= range(len(CumGDD2015.Cumu)) 
CumGDD2016['Index']= range(len(CumGDD2016.Cumu)) 
CumGDD2017['Index']= range(len(CumGDD2017.Cumu)) 
CumGDD2018['Index']= range(len(CumGDD2018)) 
CumGDD2019['Index']= range(len(CumGDD2019))

# %%
#lines= pd.concat([test,x1,x2,x3,x4,x5,x6,x7,x8,x9])
#lines['MM-DD'] = lines['Date'].dt.strftime('%m-%d')
#lines2 = lines[['MM-DD', 'GDD', 'Year']]
#sns.lineplot(data=lines2, x="MM-DD", y="GDD", hue="Year")
#fuckkk
lines= pd.concat([CumGDD2010,CumGDD2011,CumGDD2012,CumGDD2013,CumGDD2014,CumGDD2015,CumGDD2016,CumGDD2017,CumGDD2018,CumGDD2019])
lines= lines[['Date','Cumu','Year','Index']]
#lines['MM-DD'] = lines['Date'].dt.strftime('%m-%d')
#lines['Year'] = pd.DatetimeIndex(lines['Date']).year
lines['Year'] = lines['Year'].astype('category')
lines
ax =sns.lineplot(data=lines, x="Index", y="Cumu", hue="Year")
ax.set(xlabel="days", ylabel = 'GDD', title= 'Cumulative GDD by Year',rc={'figure.figsize':(20,20)})
sns_plot.savefig('GDDgraph.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-826450cbccb8> in <module>
#      11 lines
#      12 ax =sns.lineplot(data=lines, x="Index", y="Cumu", hue="Year")
# ---> 13 ax.set(xlabel="days", ylabel = 'GDD', title= 'Cumulative GDD by Year',rc={'figure.figsize':(20,20)})
#      14 sns_plot.savefig('GDDgraph.png')
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1069             sorted(kwargs.items(), reverse=True,
#    1070                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1071         return self.update(props)
#    1072
#    1073     def findobj(self, match=None, include_self=True):
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# ...

# %%
#Soil Moisture
soil_arr = [soil2010, soil2011, soil2012, soil2013, soil2014, soil2015, soil2018, soil2019]
arr_test = np.zeros(len(soil_arr))
soil_arr[3]
# Out:
#                   Time         TIME PST  Year  Month  Day            Date  \
# 0       10/1/2013 0:15  9/30/2013 16:15  2013      9   30  9/30/2013 0:00
# 1       10/1/2013 0:30  9/30/2013 16:30  2013      9   30  9/30/2013 0:00
# 2       10/1/2013 0:45  9/30/2013 16:45  2013      9   30  9/30/2013 0:00
# 3       10/1/2013 1:00  9/30/2013 17:00  2013      9   30  9/30/2013 0:00
# 4       10/1/2013 1:15  9/30/2013 17:15  2013      9   30  9/30/2013 0:00
# ...                ...              ...   ...    ...  ...             ...
# 20343  4/30/2014 23:00  4/30/2014 15:00  2014      4   30  4/30/2014 0:00
# 20344  4/30/2014 23:15  4/30/2014 15:15  2014      4   30  4/30/2014 0:00
# 20345  4/30/2014 23:30  4/30/2014 15:30  2014      4   30  4/30/2014 0:00
# 20346  4/30/2014 23:45  4/30/2014 15:45  2014      4   30  4/30/2014 0:00
# 20347    5/1/2014 0:00  4/30/2014 16:00  2014      4   30  4/30/2014 0:00
#
#        SMwfv
# 0      0.011
# 1      0.013
# 2      0.014
# 3      0.014
# ...

# %%
def clean_soil_air(df):
    df1 = df
    df1 =  df1.groupby(['Month','Day','Date'], as_index=False).mean()
    df1= df1[['Date', 'SMwfv']]
    df1['Date']= pd.to_datetime(df1['Date'])
    df_clean = df1.sort_values('Date').reset_index(drop=True)
    df_clean = df_clean.fillna(method='ffill')
    return(df_clean)

# %%
test = []
for i in range(len(soil_arr)):
    x= clean_soil_air(soil_arr[i])
    test.append(x)

# %%
test[0]['Year'] = [2010]*len(test[0]['SMwfv'])
test[1]['Year'] = [2011]*len(test[1]['SMwfv'])
test[2]['Year'] = [2012]*len(test[2]['SMwfv'])
test[3]['Year'] = [2013]*len(test[3]['SMwfv'])
test[4]['Year'] = [2014]*len(test[4]['SMwfv'])
test[5]['Year'] = [2015]*len(test[5]['SMwfv'])
test[6]['Year'] = [2018]*len(test[6]['SMwfv'])
test[7]['Year'] = [2019]*len(test[7]['SMwfv'])
boxsoil= pd.concat([test[0],test[1],test[2],test[3],test[4],test[5],test[6],test[7]])
ax= sns.boxplot(x="Year", y="SMwfv", data=boxsoil)
plt.title("AIRS BoxPlot of Soil Moisture")
plt.xlabel("Year")
plt.ylabel("Soil Moisture Level")
# Out:
# Text(0, 0.5, 'Soil Moisture Level')

# %%
soilmeanyear= boxsoil.groupby(['Year'], as_index=False).mean()
plt.plot(soilmeanyear.Year, soilmeanyear.SMwfv)
plt.title("Mean Rainfall per Year")
plt.xlabel("Year")
plt.ylabel("Rain (mm)")
# Out:
# Text(0, 0.5, 'Rain (mm)')

# %%
allsoil = boxsoil
soil_means = allsoil.groupby('Year',as_index=False).mean()
scatter_soil =Year_mean.merge(soil_means, how='inner', on='Year')

ax2=sns.scatterplot(x= 'SMwfv', y= 'GDD', data= scatter_soil)
ax2.set(xlabel="Soil Moisture", ylabel = "GDD", title='Soil Moistue')
print(scatter_soil)
# Out:
#    Year       Temp        GDD     SMwfv
# 0  2010  12.048279   574.8600  0.173127
# 1  2011  12.442472   693.4790  0.142185
# 2  2012  12.686385   740.9300  0.136385
# 3  2013  13.835692  1386.8615  0.070514
# 4  2014  14.782239   817.1890  0.104302
# 5  2015  13.533187   909.0100  0.109337
# 6  2018  12.823054   819.0650  0.169711
# 7  2019  13.488402   826.9510  0.180349

# %%
sns.set(style = "darkgrid")

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = scatter_soil['Temp']
y = scatter_soil['SMwfv']
z = scatter_soil['GDD']

ax.set_xlabel("Mean Temp")
ax.set_ylabel("Soil Moisture")
ax.set_zlabel("Observed GDD")

ax.scatter(x, y, z)

plt.show()

# %%
# Import dependencies
import plotly
import plotly.graph_objs as go

# Configure Plotly to be rendered inline in the notebook.
plotly.offline.init_notebook_mode()

# %%
# Configure the trace.
trace = go.Scatter3d(
    x = scatter_soil['Temp'],
    y = scatter_soil['SMwfv'],
    z = scatter_soil['GDD'],  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 10,
        'opacity': 0.8,
    }
)

# Configure the layout.
layout = go.Layout(
    margin={'l': 0, 'r': 0, 'b': 0, 't': 0}
)

data = [trace]

plot_figure = go.Figure(data=data, layout=layout)

# Render the plot.
plotly.offline.iplot(plot_figure)

# %%
scatter_soil.to_csv('scatter_soil.csv',index=False)

# %%
def clean_rain(df):
    df = df[['Month', 'Day', 'Date', 'Rain_mm']]
    df1 = df.groupby(['Month','Day','Date'], as_index=False).max()
    df_clean = df1
    df_clean['Date']= pd.to_datetime(df1['Date'])
    df_clean = df_clean.sort_values('Date').reset_index(drop=True)
    df_clean = df_clean[['Date','Rain_mm']]
    return(df_clean)

# %%
rain_arr = [rain2010, rain2011, rain2012, rain2013, rain2014, rain2015, rain2016, rain2017, rain2018, rain2019]
test2 = []
for i in range(len(rain_arr)):
    x= clean_rain(rain_arr[i])
    test2.append(x)
    
test2[0]['Year'] = [2010]*len(test2[0]['Rain_mm'])
test2[1]['Year'] = [2011]*len(test2[1]['Rain_mm'])
test2[2]['Year'] = [2012]*len(test2[2]['Rain_mm'])
test2[3]['Year'] = [2013]*len(test2[3]['Rain_mm'])
test2[4]['Year'] = [2014]*len(test2[4]['Rain_mm'])
test2[5]['Year'] = [2015]*len(test2[5]['Rain_mm'])
test2[6]['Year'] = [2016]*len(test2[6]['Rain_mm'])
test2[7]['Year'] = [2017]*len(test2[7]['Rain_mm'])
test2[8]['Year'] = [2018]*len(test2[8]['Rain_mm'])
test2[9]['Year'] = [2019]*len(test2[9]['Rain_mm'])

# %%
boxrain= pd.concat([test2[0],test2[1],test2[2],test2[3],test2[4],test2[5],test2[6],test2[7],test2[8],test2[9]])
ax= sns.boxplot(x="Year", y="Rain_mm", data=boxrain)

# %%
rain_mean_year= boxrain.groupby(['Year'], as_index=False).mean()
plt.plot(rain_mean_year.Year, rain_mean_year.Rain_mm)
plt.title("Mean Rainfall per Year")
plt.xlabel("Year")
plt.ylabel("Rain (mm)")

# %%
scatter_rain =Year_mean.merge(rain_mean_year, how='inner', on='Year')
ax3=sns.scatterplot(x= 'Rain_mm', y= 'GDD', data= scatter_rain)
ax3.set(xlabel="Rain (mm)", ylabel = "GDD", title='Rain vs GDD')
print(scatter_rain)

# %%
#scatter_rain.to_csv('scatter_rain.csv',index=False)
soil_all = allsoil
soil_all =soil_all.merge(box, how='inner', on=['Date', 'Year'])
soil_all
# Out:
#            Date     SMwfv  Year     Temp
# 0    2010-09-30  0.053452  2010  23.3200
# 1    2010-10-01  0.052896  2010  25.4100
# 2    2010-10-02  0.052469  2010  23.3200
# 3    2010-10-03  0.051708  2010  18.1800
# 4    2010-10-04  0.050490  2010  13.7250
# ...         ...       ...   ...      ...
# 1702 2020-04-26  0.162427  2019  18.1550
# 1703 2020-04-27  0.154156  2019  17.5960
# 1704 2020-04-28  0.147125  2019  20.7200
# 1705 2020-04-29  0.142010  2019  19.9200
# 1706 2020-04-30  0.138215  2019  19.1575
#
# [1707 rows x 4 columns]

# %%
group_soil = soil_all.groupby('Year')
year_arr = [2010, 2011, 2012, 2013,2014,2015,2018,2019]
group_arr =[]
for i in year_arr:
    x= group_soil.get_group(i).reset_index(drop=True)
    x = pd.DataFrame(x)
    group_arr.append(x)

# %%
def clean_soil_total_gdd(df):
    df1 = pd.DataFrame(df)
    df1['GDD'] =(df1['Temp'] - 6)
    return(df1)

def soil_GDD(df,val,date):
    test= df[df['SMwfv']>val].reset_index(drop=True)
    date2 = test.Date[0]
    test = df[(df.Date < date) & (df.Date>date2)].reset_index(drop=True)
    x= sum(test.GDD)
    print(date2)
    return(x)

for i in range(len(group_arr)):
    group_arr[i] = clean_soil_total_gdd(group_arr[i])

# %%
#Initializes array of variances per soil moisture value
varss = []
#creates array of soil moisture values (0,) 
val = np.linspace(0, .25, 200)
end_dates = [thresh_date2010, thresh_date2011, thresh_date2012, thresh_date2013, thresh_date2014, thresh_date2015, thresh_date2018, thresh_date2019]
Range = []
for v in val:
    GDDs= []
    r= 0
    for i in range(len(group_arr)):
        x= soil_GDD(group_arr[i],v,end_dates[i])
        print(i)
        print(v)
        GDDs.append(x)
    r = np.ptp(GDDs)
    print(r)
    Range.append(r)
    print(GDDs)
    v = np.var(GDDs)
    varss.append(v)
# Out:
# 2010-09-30 00:00:00
# 0
# 0.0
# 2011-09-30 00:00:00
# 1
# 0.0
# 2012-09-30 00:00:00
# 2
# 0.0
# 2013-09-30 00:00:00
# 3
# 0.0
# 2014-09-30 00:00:00
# 4
# 0.0
# 2015-09-30 00:00:00
# 5
# 0.0
# 2018-09-30 00:00:00
# 6
# 0.0
# 2019-09-30 00:00:00
# 7
# 0.0
# 818.0265
# [557.5400000000001, 683.3139999999996, 719.7049999999999, 1375.5665000000001, 807.4640000000002, 895.4499999999999, 809.2300000000005, 820.2520000000003]
# 2010-09-30 00:00:00
# 0
# 0.001256281407035176
# 2011-09-30 00:00:00
# 1
# 0.001256281407035176
# 2012-09-30 00:00:00
# 2
# 0.001256281407035176
# 2013-09-30 00:00:00
# 3
# 0.001256281407035176
# 2014-09-30 00:00:00
# 4
# 0.001256281407035176
# 2015-09-30 00:00:00
# 5
# 0.001256281407035176
# 2018-09-30 00:00:00
# 6
# 0.001256281407035176
# 2019-09-30 00:00:00
# 7
# 0.001256281407035176
# 818.0265
# [557.5400000000001, 683.3139999999996, 719.7049999999999, 1375.5665000000001, 807.4640000000002, 895.4499999999999, 809.2300000000005, 820.2520000000003]
# ...

# %%
GDDs
# Out:
# [0,
#  0,
#  69.44000000000003,
#  208.87000000000003,
#  16.029,
#  121.875,
#  0,
#  90.56099999999999]

# %%
gdd_dict_soil = {'Soil_thresh' : val, 'Variance': varss, 'Range': Range}
gdd_soil_df = pd.DataFrame(gdd_dict_soil)
sns.lineplot(data=gdd_soil_df, x="Soil_thresh", y="Variance")
plt.title("AIRS Variance and Soil Moisture Thresh")
plt.xlabel("Soil Moisture Level")
plt.ylabel("Variance")
# Out:
# Text(0, 0.5, 'Variance')

# %%
gdd_dict_soil = {'Soil_thresh' : val, 'Variance': varss,"Range": Range}
gdd_soil_df = pd.DataFrame(gdd_dict_soil)
sns.lineplot(data=gdd_soil_df, x="Soil_thresh", y="Range")
plt.title("AIRS Range and Soil Moisture Thresh")
plt.xlabel("Soil Moisture Level")
plt.ylabel("Range")
# Out:
# Text(0, 0.5, 'Range')

# %%
gdd_soil_df[gdd_soil_df['Variance'] == gdd_soil_df.Variance.min()]
# Out:
#      Soil_thresh     Variance     Range
# 134     0.168342  3486.722321  178.0945
# 135     0.169598  3486.722321  178.0945
# 136     0.170854  3486.722321  178.0945
# 137     0.172111  3486.722321  178.0945

# %%
def range_var_min(df):
    r_min= df[df['Range']== df.Range.min()]
    v_min = r_min[r_min['Variance'] == r_min.Variance.min()]
    mini = v_min
    return(mini)

# %%
range_var_min(gdd_soil_df)
# Out:
#      Soil_thresh     Variance    Range
# 121     0.152010  3856.240987  175.036
# 122     0.153266  3856.240987  175.036

# %%
GDDtest = []
for i in range(len(group_arr)):
        x= soil_GDD(group_arr[i],0.151759,end_dates[i])
        GDDtest.append(x)
        
GDD_revised_graph = {'GDD' :GDDtest, 'Year': year_arr}
GDD_revised_graph = pd.DataFrame(GDD_revised_graph)
GDD_revised_graph
g=sns.lineplot(data=GDD_revised_graph, x="Year", y="GDD")
plt.title("AIRS Observed Growing Degree Days With Soil Moisture Thresh = .15")
plt.xlabel("Year")
plt.ylabel("Cumulative Temps (GDD) until Green")
# Out:
# 2010-10-30 00:00:00
# 2011-11-12 00:00:00
# 2012-12-03 00:00:00
# 2014-02-28 00:00:00
# 2014-12-03 00:00:00
# 2016-01-06 00:00:00
# 2018-11-29 00:00:00
# 2019-12-02 00:00:00
# Text(0, 0.5, 'Cumulative Temps (GDD) until Green')

# %%
GDDtest = []
for i in range(len(group_arr)):
        x= soil_GDD(group_arr[i],0,end_dates[i])
        GDDtest.append(x)
        
GDD_revised_graph1 = {'GDD' :GDDtest, 'Year': year_arr}
GDD_revised_graph1 = pd.DataFrame(GDD_revised_graph1)
GDD_revised_graph1
sns.lineplot(data=GDD_revised_graph1, x="Year", y="GDD")
plt.title("AIRS Observed Growing Degree Days Without Soil Moisture Thresh")
plt.xlabel("Year")
print(np.var(GDD_revised_graph.GDD))
print(np.ptp(GDD_revised_graph.GDD))
# Out:
# 2010-09-30 00:00:00
# 2011-09-30 00:00:00
# 2012-09-30 00:00:00
# 2013-09-30 00:00:00
# 2014-09-30 00:00:00
# 2015-09-30 00:00:00
# 2018-09-30 00:00:00
# 2019-09-30 00:00:00
# 51346.91660599611
# 818.0265

# %%
x2 = GDD_revised_graph1.Year
y2= GDD_revised_graph1.GDD
plt.plot(x2, y2, label = "Without Soil Moisture")
x1 = GDD_revised_graph.Year
y1 = GDD_revised_graph.GDD
plt.plot(x1, y1, label = "With Soil Moisture .15")
plt.xlabel('Year')
plt.ylabel('GDD')
# Set a title of the current axes.
plt.title('GDD with vs without Soilmoisture ')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()
